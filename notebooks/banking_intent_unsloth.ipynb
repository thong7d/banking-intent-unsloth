# %%
from google.colab import drive
import os

# 1. Mount persistent storage
drive.mount('/content/drive')

# 2. Setup volatile workspace
# %cd /content
# !rm -rf banking-intent-unsloth
# !git clone https://github.com/thong7d/banking-intent-unsloth
# %cd banking-intent-unsloth

# 3. Install strictly versioned dependencies
# !pip install -r requirements.txt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# Cloning into 'banking-intent-unsloth'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 76 (delta 34), reused 64 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (76/76), 324.40 KiB | 1.02 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/banking-intent-unsloth
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-6rj1an9u/unsloth_29b15820b4724acc902cc8d5303d79f0
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-6rj1an9u/unsloth_29b15820b4724acc902cc8d5303d79f0
#   Resolved https://github.com/unslothai/unsloth.git to commit ac2daf8b7a4df093d597a9d1e5e6ffdb5cb0804c
#   Installing build dependencies ... done
# ...

# %%
# !python main.py --step train --env colab
# Out:
# Executing Model Training...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 1. Initializing Model and Tokenizer via Unsloth...
# ==((====))==  Unsloth 2026.4.6: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors: 100% 5.70G/5.70G [02:50<00:00, 33.5MB/s]
# Loading weights: 100% 291/291 [00:20<00:00, 14.20it/s]
# generation_config.json: 100% 239/239 [00:00<00:00, 1.01MB/s]
# config.json: 1.53kB [00:00, 5.22MB/s]
# tokenizer_config.json: 55.5kB [00:00, 120MB/s]
# ...

# %%
# !python main.py --step evaluate --env colab
# Out:
# Executing Model Evaluation...
# Evaluating Fine-tuned Model...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Loading Fine-tuned model...
# ==((====))==  Unsloth 2026.4.6: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors: 100% 5.70G/5.70G [00:55<00:00, 104MB/s]
# Loading weights: 100% 291/291 [00:20<00:00, 14.35it/s]
# generation_config.json: 100% 239/239 [00:00<00:00, 1.36MB/s]
# config.json: 1.53kB [00:00, 4.26MB/s]
# tokenizer_config.json: 55.5kB [00:00, 118MB/s]
# ...

# %%
# !python main.py --step infer --env colab
# Out:
# Executing Standalone Inference...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Loading Model from: /content/drive/MyDrive/banking-intent-unsloth/outputs/banking-intent-llama31-8b
# ==((====))==  Unsloth 2026.4.6: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights: 100% 291/291 [00:17<00:00, 16.23it/s]
# config.json: 1.53kB [00:00, 5.14MB/s]
# tokenizer_config.json: 55.5kB [00:00, 124MB/s]
# tokenizer.json: 100% 17.2M/17.2M [00:00<00:00, 27.8MB/s]
# ...
